# %%
import requests

page = requests.get('https://www.theindiantalks.com/business/career-advancement-and-opportunities-with-cbap-certification/40925/')

page.content
# Out:
# b'<!doctype html >\n<!--[if IE 8]>    <html class="ie8" lang="en"> <![endif]-->\n<!--[if IE 9]>    <html class="ie9" lang="en"> <![endif]-->\n<!--[if gt IE 8]><!--> <html lang="en-US"> <!--<![endif]-->\n<head>\n\t                <meta name="msvalidate.01" content="894853D8A020F4F0BFA139B89C8D6BB2" />\n    <title>Career advancement and opportunities with CBAP Certification</title>\n    <meta charset="UTF-8" />\n    <meta name="viewport" content="width=device-width, initial-scale=1.0">\n    <link rel="pingback" href="https://www.theindiantalks.com/xmlrpc.php" />\n    <meta property="og:image" content="https://www.theindiantalks.com/wp-content/uploads/2020/11/cbap-certification-preparation.png" /><link rel="icon" type="image/png" href="https://www.theindiantalks.com/wp-content/uploads/2020/06/output-onlinepngtools-6.png"><link rel="apple-touch-icon-precomposed" sizes="76x76" href="https://www.theindiantalks.com/wp-content/uploads/2020/06/output-onlinepngtools-7.png"/>\n\t<!-- This site 
# ...

# %%
page.status_code
# Out:
# 200

# %%
from bs4 import BeautifulSoup

soap = BeautifulSoup(page.content, 'html.parser')

text = ''

for para in soap.find_all('p'):
    text = text+para.get_text()

# %%
text
# Out:
# 'Nowadays, many jobs have a clearly defined role and have a successful career path. However, the career path of the business analyst continues to differ along with position to position descriptions. The business analyst must combine business needs with IT tools as mediator, coordinator, collaborator, and ambassador.Clear communicators, efficient coordinators, quantitative analyzers, and team players are typically good business analysts. The ideal analyst also offers the flexibility of different organizational, economic, technological, professional, and architectural roles.Certified Business Analysis Professional (CBAP) is the IIBA Business Analysis credential. CBAP is one of the most globally recognized and respected certificates in the world. CBAP certification can be invaluable if you are a specialist with more than five years of experience. It gives tremendous value to a specialist involved in requirement analysis, device analysis, and business consulting. The testing of the appli
# ...
